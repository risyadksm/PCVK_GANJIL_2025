# %% [markdown]
# <a href="https://colab.research.google.com/github/risyadksm/PCVK_GANJIL_2025/blob/main/W2_TASK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = np.zeros(shape=(500, 650, 3), dtype=np.uint8)

cv2.line(img, pt1=(20, 40), pt2=(580, 40), color=(255, 255, 255), thickness=2)

cv2.rectangle(img, pt1=(40, 80), pt2=(260, 200), color=(0, 255, 255), thickness=3)

cv2.rectangle(img, pt1=(300, 80), pt2=(560, 200), color=(255, 0, 0), thickness=-1)

cv2.circle(img, center=(140, 330), radius=75, color=(0, 0, 255), thickness=3)

font = cv2.FONT_HERSHEY_DUPLEX
cv2.putText(img, text='OpenCV Shapes', org=(40, 280), fontFace=font, fontScale=1, color=(255, 255, 255), thickness=2, lineType=cv2.LINE_AA)

cv2.arrowedLine(img, pt1=(40, 400), pt2=(250, 400), color=(255, 255, 0), thickness=3)

cv2.circle(img, center=(350, 330), radius=60, color=(0, 255, 0), thickness=-1)

cv2.ellipse(img, center=(530, 370), axes=(70, 40), angle=20, startAngle=0, endAngle=360, color=(255, 255, 0), thickness=3)

pts_pentagon = np.array([[470, 260],
                         [540, 310],
                         [510, 380],
                         [440, 380],
                         [410, 310]], np.int32)
pts_pentagon = pts_pentagon.reshape((-1, 1, 2))

cv2.polylines(img, [pts_pentagon], isClosed=True, color=(255, 0, 255), thickness=3)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("PCVK MRTI - D3 Soal No 1")
plt.axis('on')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-74c8f323-985a-439f-8438-43551cd10e82" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74c8f323-985a-439f-8438-43551cd10e82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread("KTP1.jpg")
cv2_imshow(img)

print("Resolusi gambar :", img.shape[1], "x", img.shape[0])
# Out:
# <PIL.Image.Image image mode=RGB size=720x480>
# Resolusi gambar : 720 x 480

# %%
img2  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.subplot(1, 2, 1)
plt.imshow(img_gray)
plt.title("Tanpa cmap")

plt.subplot(1, 2, 2)
plt.imshow(img_gray, cmap="gray")
plt.title("Dengan cmap")

plt.show()

# %%
img = cv2.imread('KTP1.jpg')

if img is None:
    print("Error: Gambar 'KTP1.jpg' tidak ditemukan.")
else:
    x1, y1 = 95, 50
    x2, y2 = 700, 415

    cropped_image = img[y1:y2, x1:x2]
    cv2.imwrite('KTP1_cropped.jpg', cropped_image)

    print("Menampilkan gambar asli:")
    cv2_imshow(img)

    print("\nMenampilkan hasil crop:")
    cv2_imshow(cropped_image)

    print("\nGambar berhasil di-crop dan disimpan sebagai 'KTP1_cropped.jpg'")
# Out:
# Menampilkan gambar asli:
# <PIL.Image.Image image mode=RGB size=720x480>
# Menampilkan hasil crop:
# <PIL.Image.Image image mode=RGB size=605x365>
# Gambar berhasil di-crop dan disimpan sebagai 'KTP1_cropped.jpg'

# %%
import os
cv2_imshow(cropped_image)

height, width, channels = cropped_image.shape
print(f"\n2. Dimensi (pixel):")
print(f"   - Tinggi (Height): {height} pixel")
print(f"   - Lebar (Width): {width} pixel")
print(f"   - Jumlah Channel: {channels}")

file_size_bytes = os.path.getsize('KTP1_cropped.jpg')
file_size_kb = file_size_bytes / 1024

print(f"\n3. Ukuran File:")
print(f"   - Ukuran dalam Bytes: {file_size_bytes} Bytes")
print(f"   - Ukuran dalam Kilobytes (KB): {file_size_kb:.2f} KB")
# Out:
# <PIL.Image.Image image mode=RGB size=605x365>
# 2. Dimensi (pixel):
#    - Tinggi (Height): 365 pixel
#    - Lebar (Width): 605 pixel
#    - Jumlah Channel: 3
#
# 3. Ukuran File:
#    - Ukuran dalam Bytes: 99981 Bytes
#    - Ukuran dalam Kilobytes (KB): 97.64 KB

# %%
img_rgb = cv2.cvtColor(img_edit, cv2.COLOR_BGR2RGB)

cv2.rectangle(img_edit, (150, 60), (410, 75), (255, 100, 100), -1) # Tutup Nomor NIK
cv2.rectangle(img_edit, (165, 90), (350, 105), (100, 255, 100), -1) # Tutup Nama
cv2.rectangle(img_edit, (165, 145), (430, 160), (100, 255, 100), -1) # Tutup Alamat Jalan
cv2.rectangle(img_edit, (165, 215), (230, 230), (150, 100, 255), -1) # Tutup Alamat "Kecamatan"
cv2.rectangle(img_edit, (480, 255), (570, 285), (255, 165, 0), -1) # Tutup Lokasi & Tanggal Dikeluarkan

print("\n--- Hasil Edit (Bagian KTP ditutup) ---")
plt.imshow(img_rgb)
plt.title("PCVK MRTI - D3 Soal No 2 - 5")
plt.show()
# Out:
# --- Hasil Edit (Bagian KTP ditutup) ---

# %% [markdown]
# ## **PERTANYAAN PRAKTIKUM D3**
# **1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?**
# > Perbedaan utamanya terletak pada gambar yang ditampilkan ketika kode dijalankan, ketika tanpa matplotlib plot/gambar hanya akan tersimpan ke file sedangkan menggunakan matplotlib plot/gambar akan tampil pada cell ketika kode dijalankan.
#
#
#
# **2. Apakah perbedaan dan pengaruhnya pembuatan *black image* antara tipe data
# `int16` dan `int32`?**
# > Perbedaannya terletak pada ukuran bit tiap piksel (*bit depth*) dan rentang nilai piksel yang bisa disimpan. Tipe data `int16` memiliki lebar 16 bit dengan rentang nilai ±2.147.483.648. Penggunaan `int32`menghasilkan konsumsi memori dua kali lebih besar dibanding `int16`, tanpa memberikan perbedaan visual pada *black image* karena seluruh piksel bernilai nol.
#
#
# **3. Apakah perbedaan menampilkan gambar dengan: `cv2_imshow()` dan
# `plt.imshow()`?**
# > Perbedaannya terletak pada fungsi dimana `cv2_imshow()` untuk menampilkan citra pada notebook di Google Colab dengan format warna default OpenCV yakni BGR (Blue, Green, Red). Sedangkan `plt.imshow()` fungsi dari `matplotlib` untuk menampilkan citra di dalam plot grafik dengan format warna default RGB.
#
# **4. Apakah fungsi `isClosed=True` pada baris code berikut ini**
# ![asdasq.png](data:image/png;base64,...)
# > Parameter isClosed=True pada fungsi cv2.polylines() digunakan untuk menghubungkan / menutup titik terakhir dengan titik pertama pada rangkaian titik polylines yang digambar. Jika true maka akan membentuk bangun tertutup seperti segitiga, persegi, dll sedangkan jika false akan menjadi garis saja.
